# %%
import pandas as pd
import csv

# %%
# attributes for each product
cu_attr = pd.read_csv('/Users/ruthvik/Downloads/Cumulative attributes.csv')
cu_attr.head()
# Out:
#    rank                                               link Answered_Questions  \
# 0     1  /TRUFF-Truffle-Limited-Coriander-Experience/dp...                 13
# 1     2  /nutpods-Peppermint-unsweetened-dairy-free-cre...                 12
# 2     3  /Oreo-Covered-Chocolate-Sandwich-Original/dp/B...                  0
# 3     4  /MS-Chocolate-Christmas-Holiday-Baking/dp/B07T...                  0
# 4     5                                    /dp/B0822LFHZC/                  0
#
#           Price Price.1 Discount customer_review_count category
# 0         34.99   34.99        0                    50  grocery
# 1         13.95   13.95        0                   237  grocery
# 2          8.98    8.98        0                     0  grocery
# 3  99.99-129.99     115        0                     0  grocery
# 4          9.98    9.98        0                     0  grocery

# %%
# sentiment score file 
sentiment = pd.read_csv('/Users/ruthvik/Downloads/amazon data/Reviews/cumulative reviews.csv')
sentiment.head()
# Out:
#    rank category                                             review  \
# 0     1       pc  I see so many people on here who are technolog...
# 1     1       pc  Why was my initial review removed?I was about ...
# 2     1       pc  NOV 16, 2019 - If I could, I'd drop this to 2....
# 3     1       pc  We offer an app to thousands of restaurants th...
# 4     1       pc  I am so glad I pre-ordered my new Fire! I've b...
#
#    sentiment score
# 0         0.034399
# 1         0.057822
# 2         0.150000
# 3         0.921609
# 4         0.971700

# %%
# aggregating sentiment by rank and category
sentiment1 = sentiment.groupby(['rank','category'], as_index = False).agg({'sentiment score': ['mean']})
sentiment1.columns = sentiment1.columns.get_level_values(0)

# exporting to csv file
sentiment1.to_csv("cumulative_scores.csv", index = False)

# %%
# sentiment score file 
sentiment = pd.read_csv('/Users/ruthvik/Downloads/cumulative_scores.csv')
sentiment.head()
# Out:
#    rank     category  sentiment score
# 0     1  electronics         0.507931
# 1     1      fashion         0.980166
# 2     1      grocery         0.651473
# 3     1    homeneeds         0.420256
# 4     1           pc         0.514621

# %%
links = pd.read_csv('/Users/ruthvik/Downloads/amazon data/Links/Cumulative links.csv')
links.head()
# Out:
#    rank category                                       product_link  \
# 0     1     toys  /LEGO-Advent-Calendar-60235-Building/dp/B07NRT...
# 1     2     toys     /L-L-Surprise-Amazing-Surprises/dp/B07PMN4NJD/
# 2     3     toys     /PJ-Masks-95686-Advent-Calendar/dp/B07Q4QYWP2/
# 3     4     toys     /Frozen-12902-Styling-Head-Elsa/dp/B074B6XXWB/
# 4     5     toys       /L-L-Surprise-Secret-Dollface/dp/B07PMN4BZP/
#
#                                                 name          avg_rating  \
# 0              LEGO City Advent Calendar 60235 Bu...  4.7 out of 5 stars
# 1              L.O.L. Surprise! Amazing Surprise ...  4.6 out of 5 stars
# 2              PJ Masks Advent Calendar - Amazon ...  5.0 out of 5 stars
# 3                 Frozen Styling Head - Elsa          3.3 out of 5 stars
# 4              L.O.L. Surprise! O.M.G. Winter Dis...  4.4 out of 5 stars
#
#                     rating_link rating_count  prime Images
# 0  /product-reviews/B07NRT2CYD/          101  prime      7
# 1  /product-reviews/B07PMN4NJD/          108  prime      6
# 2  /product-reviews/B07Q4QYWP2/            2  prime      3
# 3  /product-reviews/B074B6XXWB/           61  prime      7
# 4  /product-reviews/B07PMN4BZP/           64  prime      6

# %%
a = links.merge(sentiment, on=['rank','category'], how='left')
a.head()
# Out:
#    rank category                                       product_link  \
# 0     1     toys  /LEGO-Advent-Calendar-60235-Building/dp/B07NRT...
# 1     2     toys     /L-L-Surprise-Amazing-Surprises/dp/B07PMN4NJD/
# 2     3     toys     /PJ-Masks-95686-Advent-Calendar/dp/B07Q4QYWP2/
# 3     4     toys     /Frozen-12902-Styling-Head-Elsa/dp/B074B6XXWB/
# 4     5     toys       /L-L-Surprise-Secret-Dollface/dp/B07PMN4BZP/
#
#                                                 name          avg_rating  \
# 0              LEGO City Advent Calendar 60235 Bu...  4.7 out of 5 stars
# 1              L.O.L. Surprise! Amazing Surprise ...  4.6 out of 5 stars
# 2              PJ Masks Advent Calendar - Amazon ...  5.0 out of 5 stars
# 3                 Frozen Styling Head - Elsa          3.3 out of 5 stars
# 4              L.O.L. Surprise! O.M.G. Winter Dis...  4.4 out of 5 stars
#
#                     rating_link rating_count  prime Images  sentiment score
# 0  /product-reviews/B07NRT2CYD/          101  prime      7         0.715670
# 1  /product-reviews/B07PMN4NJD/          108  prime      6         0.825684
# 2  /product-reviews/B07Q4QYWP2/            2  prime      3         0.947291
# 3  /product-reviews/B074B6XXWB/           61  prime      7         0.255545
# 4  /product-reviews/B07PMN4BZP/           64  prime      6         0.540297

# %%
b = a.merge(cu_attr, on = ['rank', 'category'], how = 'left')
b.head()
# Out:
#    rank category                                       product_link  \
# 0     1     toys  /LEGO-Advent-Calendar-60235-Building/dp/B07NRT...
# 1     2     toys     /L-L-Surprise-Amazing-Surprises/dp/B07PMN4NJD/
# 2     3     toys     /PJ-Masks-95686-Advent-Calendar/dp/B07Q4QYWP2/
# 3     4     toys     /Frozen-12902-Styling-Head-Elsa/dp/B074B6XXWB/
# 4     5     toys       /L-L-Surprise-Secret-Dollface/dp/B07PMN4BZP/
#
#                                                 name          avg_rating  \
# 0              LEGO City Advent Calendar 60235 Bu...  4.7 out of 5 stars
# 1              L.O.L. Surprise! Amazing Surprise ...  4.6 out of 5 stars
# 2              PJ Masks Advent Calendar - Amazon ...  5.0 out of 5 stars
# 3                 Frozen Styling Head - Elsa          3.3 out of 5 stars
# 4              L.O.L. Surprise! O.M.G. Winter Dis...  4.4 out of 5 stars
#
#                     rating_link rating_count  prime Images  sentiment score  \
# 0  /product-reviews/B07NRT2CYD/          101  prime      7         0.715670
# 1  /product-reviews/B07PMN4NJD/          108  prime      6         0.825684
# 2  /product-reviews/B07Q4QYWP2/            2  prime      3         0.947291
# 3  /product-reviews/B074B6XXWB/           61  prime      7         0.255545
# 4  /product-reviews/B07PMN4BZP/           64  prime      6         0.540297
#
#                                                 link Answered_Questions  \
# 0  /LEGO-Advent-Calendar-60235-Building/dp/B07NRT...                 16
# 1     /L-L-Surprise-Amazing-Surprises/dp/B07PMN4NJD/                 27
# 2     /PJ-Masks-95686-Advent-Calendar/dp/B07Q4QYWP2/                  0
# 3     /Frozen-12902-Styling-Head-Elsa/dp/B074B6XXWB/                  0
# 4       /L-L-Surprise-Secret-Dollface/dp/B07PMN4BZP/                 17
#
#      Price Price.1 Discount customer_review_count
# 0  $26.90     26.9       72                     0
# 1     $98       98       89                    25
# 2   $9.99     9.99        3                    66
# 3  $14.88    14.88       60                     0
# 4  $55.95    55.95       42                     0

# %%
b['avg_rating'] = b['avg_rating'].str[:3]

# %%
b.to_csv('modelfile.csv', index = False)
